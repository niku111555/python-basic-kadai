# %%
user_names = ["侍太郎", "侍一郎", "侍次郎", "侍三郎", "侍四郎"]
print(user_names[1]) # 2番目の要素だけ表示

user_names[1] = "侍花子" # 2番目の要素を更新
print(user_names)

user_names.append("侍五郎") # 6番目の要素に追加
print(user_names)

user_names.pop(2) # 3番目の要素を削除(0始まりのため2を指定)
print(user_names)
# Out:
# 侍一郎
# ['侍太郎', '侍花子', '侍次郎', '侍三郎', '侍四郎']
# ['侍太郎', '侍花子', '侍次郎', '侍三郎', '侍四郎', '侍五郎']
# ['侍太郎', '侍花子', '侍三郎', '侍四郎', '侍五郎']

# %%
# 朝のあいさつを出力する関数を作成する
def say_good_morning():
    print("おはようございます！")
    print("昨日はよく眠れましたか？")
    print("今日も1日頑張りましょう！")

# 夜のあいさつを出力する関数を作成する
def say_good_evening():
    print("こんばんは！")
    print("今日も一日お疲れ様でした。")

# 朝のあいさつを出力する関数を呼び出す
say_good_morning()

# 夜のあいさつを出力する関数を呼び出す
say_good_evening()
# Out:
# おはようございます！
# 昨日はよく眠れましたか？
# 今日も1日頑張りましょう！
# こんばんは！
# 今日も一日お疲れ様でした。

# %%
personal_data = {"name": "侍太郎", "age": 36, "gender": "男性"}

# 連想配列personal_dataのキーと値を1つずつ順番に出力する
for key, value in personal_data.items():
    print(f"{key}は{value}です。")

# 連想配列personal_dataの値を1つずつ順番に出力する
for value in personal_data.values():
    print(value)
# Out:
# nameは侍太郎です。
# ageは36です。
# genderは男性です。
# 侍太郎
# 36
# 男性

# %%
array = ["水","金","地","火","木","土","天","海","冥"]
for i in array:
    print(i)
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥

# %%
arrays = ["水", "金", "地", "火", "木", "土", "天", "海", "冥"]

i = 0

while i < 9:
    print(arrays[i])
    i = i + 1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥

# %% [markdown]
# # 新しいセクション

# %%
# 与えられた引数$priceに送料を加算し、その値を出力する関数を定義する
def calculate_total(price):
    # 与えられた引数priceに送料を加算し、変数totalに代入する
    total = price + 500

    # 変数totalの値を出力する
    print(f"{total}円")

# 関数を呼び出し、引数として購入金爆を渡す
calculate_total(1200)
# Out:
# 1700円

# %%
weekly_weather = ["月曜日は晴れです","火曜日は雨です","水曜日は晴れです","木曜日は晴れです","金曜日は曇りです","土曜日は曇りのち雨です","日曜日は雷雨です"]
print(weekly_weather[2]) # 3番目の要素だけ表示

weekly_weather = {"mon":"晴れ","tue":"雨","wed":"晴れ","thu":"晴れ","fri":"曇り","sat":"曇りのち雨","sun":"雷雨"}
 # キー「wed」の値を表示
print(weekly_weather["wed"])
# Out:
# 水曜日は晴れです
# 晴れ

# %%
print(45 + 18) # 算術演算子を使った場合の戻り値を出力する
print(45 > 18) # 比較演算子を使った場合の戻り値を出力する
# Out:
# 63
# True

# %%
#ランダムな整数を利用するために、randomモジュールをインポート
import random

# 変数numに0〜4までのランダムな整数を代入する
num = random.randint(0, 4)

# 変数numの値を出力
print(num)

# 変数numの値が4であれば、「大当たりです」という文字列を出力する
if num == 4:
  print("大当たりです")
elif num == 3:
  print("あたりです")
else:
  print("はずれです")
# Out:
# 0
# はずれです

# %%
#ランダムな整数を利用するために、randomモジュールをインポート
import random

# 変数numにnumに0〜4までのランダムな整数を代入する
num = random.randint(0, 4)

# 変数numの値を出力
print(num)

# すべての条件が成り立つ場合にのみ処理を行う（変数numの値が2）
if 1 < num and num < 3:
    print("変数numは１より大きく、3より小さいです")
else:
  print("and条件が成り立ちませんでした")

# 1つでも条件が成り立てば処理を行う（変数numの値が1または3）
if num == 1 or num == 3:
  print("変数numは1または3です")
else:
  print("or条件が成り立ちませんでした")
# Out:
# 3
# and条件が成り立ちませんでした
# 変数numは1または3です

# %%
# 連想配列を作成
personal_data = {"name":"侍太郎","age":36,"gender":"男性"}

# キー「name」の値を表示
print(personal_data["name"])

# 連想配列全体を表示
print(personal_data)

# キー「age」の値を更新
personal_data["age"] = 37

# 新しく要素（キーと値）を追加
personal_data["address"] = "東京都"

# 連想配列全体を表示
print(personal_data)
# Out:
# 侍太郎
# {'name': '侍太郎', 'age': 36, 'gender': '男性'}
# {'name': '侍太郎', 'age': 37, 'gender': '男性', 'address': '東京都'}

# %%
country_names = ("日本","アメリカ","イギリス","フランス")
# 3番目の要素を取り出す
print(country_names[2])

# 全ての要素を取り出す
print(country_names)
# Out:
# イギリス
# ('日本', 'アメリカ', 'イギリス', 'フランス')

# %%
country_names = {"アメリカ","イギリス","日本","フランス"}
# セット全体を表示
print(country_names)

country_names.add("ドイツ") # 「ドイツ」をセットに追加
print(country_names)

country_names.remove("イギリス") # セットから「イギリス」を削除
print(country_names)
# Out:
# {'日本', 'イギリス', 'フランス', 'アメリカ'}
# {'フランス', 'イギリス', '日本', 'ドイツ', 'アメリカ'}
# {'フランス', '日本', 'ドイツ', 'アメリカ'}

# %%
#台形の面積の計算
number1 = 10
number2 = 20
number3 = 5
area = ((number1 + number2) * number3 / 2)
print(area, "cm²")
# Out:
# 75.0 cm²

# %%
user_name = "風花"
print(user_name)
# Out:
# 風花

# %%
# 整数型と浮動小数点型の足し算
number1 = 5
number2 = 2.5
print(number1 + number2)

# 文字列型と文字列型の連結
last_name  = "侍"
first_name = "太郎"
print(last_name + first_name)
# Out:
# 7.5
# 侍太郎

# %%
last_name   = "侍"
first_name  = "太郎"
sister_name = "花子"

# 3つの変数を文字列内に埋め込んで表示
print(f"私の名前は{last_name}{first_name}です。妹の名前は{sister_name}です。")
# Out:
# 私の名前は侍太郎です。妹の名前は花子です。
